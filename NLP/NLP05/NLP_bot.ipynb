# %% [markdown]
# <a href="https://colab.research.google.com/github/NAZCAcreative/AIFFEL_quest_eng/blob/main/NLP/NLP05/NLP_bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NLP_LLM_NODE
